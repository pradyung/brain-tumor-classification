# %%
from load_data import load_data
import matplotlib.pyplot as plt

# %%
x_train, Y_train, x_test, Y_test = load_data()

# flattening images
X_train = x_train.reshape(len(x_train), -1)
X_test = x_test.reshape(len(x_test), -1)

# %%
from keras.layers import Dense
from keras.models import Sequential

model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(4, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, batch_size=32, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 179/179 [==============================] - 42s 231ms/step - loss: 4.0888 - accuracy: 0.5116
# Epoch 2/10
# 179/179 [==============================] - 42s 234ms/step - loss: 1.6143 - accuracy: 0.6213
# Epoch 3/10
# 179/179 [==============================] - 42s 233ms/step - loss: 1.0237 - accuracy: 0.6856
# Epoch 4/10
# 179/179 [==============================] - 41s 230ms/step - loss: 0.8392 - accuracy: 0.7064
# Epoch 5/10
# 179/179 [==============================] - 41s 231ms/step - loss: 0.6208 - accuracy: 0.7628
# Epoch 6/10
# 179/179 [==============================] - 41s 231ms/step - loss: 0.5666 - accuracy: 0.7859
# Epoch 7/10
# 179/179 [==============================] - 41s 231ms/step - loss: 0.5259 - accuracy: 0.8078
# Epoch 8/10
# 179/179 [==============================] - 41s 231ms/step - loss: 0.4966 - accuracy: 0.8148
# Epoch 9/10
# 179/179 [==============================] - 41s 232ms/step - loss: 0.4349 - accuracy: 0.8395
# Epoch 10/10
# 179/179 [==============================] - 41s 229ms/step - loss: 0.4140 - accuracy: 0.8435

# %%
plt.title("Basic Model Accuracy")
plt.plot(history.history['accuracy'])
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
score = model.evaluate(X_test, Y_test, verbose=0)
print(dict(zip(model.metrics_names, score)))
# Out:
# {'loss': 0.866847813129425, 'accuracy': 0.7307398915290833}
